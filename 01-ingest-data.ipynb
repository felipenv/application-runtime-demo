# %% [markdown]
# ## Install requirements

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ### explore functions natively to fetch data

# %%
import pandas as pd
import geopandas as gpd
import yaml

from src.fetch_poi import FetchPoi
from src.hexes import Hexes
from src.score_poi import ScorePoi

# %%
    config = yaml.safe_load(open("config/config.yaml"))

# %%
    # get hexes for location
    hexes = Hexes(place=config['location'])
    hexes.get_place_hex(h3_resolution=config['h3_resolution'])

# %%
    fetch = FetchPoi(config['location'], osm_endpoint=config['overpass_endpoint'])
    datasets = {}

# %%
hex_scores = hexes.place_hexes

# %%
    for dataset in config['datasets']:
        print(f'fetching {dataset}')
        if dataset not in datasets:
            tag = config['datasets'][dataset]['tag']
            values = config['datasets'][dataset]['values']
            _, datasets[dataset] = fetch.fetch_data(tag=tag, values=values)
            datasets[dataset]['lat'] = datasets[dataset]['centroid'].apply(lambda x: x.y)
            datasets[dataset]['lon'] = datasets[dataset]['centroid'].apply(lambda x: x.x)
            datasets[dataset].dropna(subset=tag, inplace=True)
            datasets[dataset] = datasets[dataset].loc[:, datasets[dataset].isnull().mean() < .3]
            scoring = ScorePoi(datasets[dataset], k=100, d=500)
            hex_scores = scoring.score_poi(hex_scores, poi_name=dataset, aggregation='sum')
# Out:
# fetching amenity
# 100%|██████████| 9/9 [00:00<00:00, 1001.80it/s]
# INFO:root:getting data per grid for London....
#
# 100%|██████████| 33/33 [01:17<00:00,  2.36s/it]
# INFO:root:Computing geometry from lat, lon
# INFO:root:Computing circles of interest based on parameters k and d.
#                       current values: k = 100, d = 500
# /User/demos/application-runtime/src/score_poi.py:44: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   self.data['centroid'] = self.data.geometry.centroid
# INFO:root:getting hexagons influenced by POI according to distances k and d...
# /User/demos/application-runtime/src/score_poi.py:57: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:3035
# Right CRS: None
#
#   candidate_hexes = gpd.sjoin(hexagons.to_crs(3035), self.data[['circle_of_interest']])
# INFO:root:filtering POIs matching hexes...
# /User/demos/application-runtime/src/score_poi.py:62: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:3035
#
#   candidate_poi = gpd.sjoin(self.data, hexagons[['geometry']].to_crs(3035), how='inner')
# INFO:root:computing scores for data...
# INFO:root:getting distances between poi and hexagon centroids...
# fetching shop
# 100%|██████████| 9/9 [00:00<00:00, 982.89it/s]
# INFO:root:getting data per grid for London....
#
# 100%|██████████| 33/33 [00:48<00:00,  1.47s/it]
# INFO:root:Computing geometry from lat, lon
# INFO:root:Computing circles of interest based on parameters k and d.
#                       current values: k = 100, d = 500
# /User/demos/application-runtime/src/score_poi.py:44: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   self.data['centroid'] = self.data.geometry.centroid
# INFO:root:getting hexagons influenced by POI according to distances k and d...
# /User/demos/application-runtime/src/score_poi.py:57: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:3035
# Right CRS: None
#
#   candidate_hexes = gpd.sjoin(hexagons.to_crs(3035), self.data[['circle_of_interest']])
# INFO:root:filtering POIs matching hexes...
# /User/demos/application-runtime/src/score_poi.py:62: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:3035
#
#   candidate_poi = gpd.sjoin(self.data, hexagons[['geometry']].to_crs(3035), how='inner')
# INFO:root:computing scores for data...
# INFO:root:getting distances between poi and hexagon centroids...
# fetching leisure
# 100%|██████████| 9/9 [00:00<00:00, 949.27it/s]
# INFO:root:getting data per grid for London....
#
# 100%|██████████| 33/33 [00:37<00:00,  1.14s/it]
# INFO:root:Computing geometry from lat, lon
# INFO:root:Computing circles of interest based on parameters k and d.
#                       current values: k = 100, d = 500
# /User/demos/application-runtime/src/score_poi.py:44: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   self.data['centroid'] = self.data.geometry.centroid
# INFO:root:getting hexagons influenced by POI according to distances k and d...
# /User/demos/application-runtime/src/score_poi.py:57: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:3035
# Right CRS: None
#
#   candidate_hexes = gpd.sjoin(hexagons.to_crs(3035), self.data[['circle_of_interest']])
# INFO:root:filtering POIs matching hexes...
# /User/demos/application-runtime/src/score_poi.py:62: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:3035
#
#   candidate_poi = gpd.sjoin(self.data, hexagons[['geometry']].to_crs(3035), how='inner')
# INFO:root:computing scores for data...
# INFO:root:getting distances between poi and hexagon centroids...
# fetching highway
# 100%|██████████| 9/9 [00:00<00:00, 837.48it/s]
# INFO:root:getting data per grid for London....
#
# 100%|██████████| 33/33 [00:55<00:00,  1.69s/it]
# INFO:root:Computing geometry from lat, lon
# INFO:root:Computing circles of interest based on parameters k and d.
#                       current values: k = 100, d = 500
# /User/demos/application-runtime/src/score_poi.py:44: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   self.data['centroid'] = self.data.geometry.centroid
# INFO:root:getting hexagons influenced by POI according to distances k and d...
# /User/demos/application-runtime/src/score_poi.py:57: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:3035
# Right CRS: None
#
#   candidate_hexes = gpd.sjoin(hexagons.to_crs(3035), self.data[['circle_of_interest']])
# INFO:root:filtering POIs matching hexes...
# /User/demos/application-runtime/src/score_poi.py:62: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:3035
#
#   candidate_poi = gpd.sjoin(self.data, hexagons[['geometry']].to_crs(3035), how='inner')
# INFO:root:computing scores for data...
# INFO:root:getting distances between poi and hexagon centroids...
# fetching railway
# 100%|██████████| 9/9 [00:00<00:00, 998.14it/s]
# INFO:root:getting data per grid for London....
#
# 100%|██████████| 33/33 [00:32<00:00,  1.02it/s]
# INFO:root:Computing geometry from lat, lon
# INFO:root:Computing circles of interest based on parameters k and d.
#                       current values: k = 100, d = 500
# /User/demos/application-runtime/src/score_poi.py:44: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   self.data['centroid'] = self.data.geometry.centroid
# INFO:root:getting hexagons influenced by POI according to distances k and d...
# /User/demos/application-runtime/src/score_poi.py:57: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:3035
# Right CRS: None
#
#   candidate_hexes = gpd.sjoin(hexagons.to_crs(3035), self.data[['circle_of_interest']])
# INFO:root:filtering POIs matching hexes...
# /User/demos/application-runtime/src/score_poi.py:62: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:3035
#
#   candidate_poi = gpd.sjoin(self.data, hexagons[['geometry']].to_crs(3035), how='inner')
# INFO:root:computing scores for data...
# INFO:root:getting distances between poi and hexagon centroids...

# %%
hex_scores
# Out:
#                hex_id                                           geometry  \
# 0     88195dadb3fffff  POLYGON ((-0.48146 51.50856, -0.48818 51.50734...
# 1     88195db485fffff  POLYGON ((-0.09288 51.66737, -0.09960 51.66619...
# 2     88194ad08bfffff  POLYGON ((-0.00511 51.40646, -0.01180 51.40527...
# 3     88195dacc5fffff  POLYGON ((-0.38926 51.54225, -0.39599 51.54104...
# 4     88194ad5c1fffff  POLYGON ((0.05349 51.31897, 0.04681 51.31778, ...
# ...               ...                                                ...
# 2401  88194ad987fffff  POLYGON ((-0.33633 51.40676, -0.34304 51.40555...
# 2402  88194e6d11fffff  POLYGON ((0.11433 51.47015, 0.10764 51.46897, ...
# 2403  88194e6db5fffff  POLYGON ((0.09947 51.41650, 0.09278 51.41532, ...
# 2404  88194e6aedfffff  POLYGON ((0.09494 51.60693, 0.08823 51.60575, ...
# 2405  88194e6e21fffff  POLYGON ((0.20214 51.51107, 0.19544 51.50989, ...
#
#       score_amenity  score_shop  score_leisure  score_highway  score_railway
# 0          8.340623    0.385595       0.000000      16.020005       0.302102
# 1         17.070924    0.577442       0.401325      34.676886       1.190289
# 2         11.552341    0.000000       6.326450      51.740510       0.670263
# 3          6.432914    2.281679       0.000000      25.557636       0.000000
# 4          5.278275    0.157626       1.540873      15.927384       0.000000
# ...             ...         ...            ...            ...            ...
# 2401      20.409464    0.266839       1.000000      24.665717       1.087481
# 2402      15.908132    3.621407       0.416125      41.867790       0.579252
# 2403       7.051774    0.350400       2.361531      27.010386       0.000000
# 2404       6.550627    1.195497       4.097375      31.087521       1.719024
# 2405       1.261046    0.000000       0.000000       5.628164       0.125359
#
# [2406 rows x 7 columns]

# %%
fetch.place_map
# Out:
#                                             geometry  bbox_north  bbox_south  \
# 0  POLYGON ((-0.51038 51.46809, -0.51036 51.46795...   51.691874    51.28676
#
#    bbox_east  bbox_west   place_id  osm_type  osm_id        lat       lon  \
# 0   0.334016  -0.510375  273846562  relation   65606  51.489334 -0.144055
#
#       class        type  place_rank  importance addresstype    name  \
# 0  boundary  ceremonial          25    0.882089        city  London
#
#                                       display_name
# 0  London, Greater London, England, United Kingdom

# %% [markdown]
# ## Merge all geodataframes into one

# %%
import pandas as pd

# %%
all_data = pd.DataFrame()

# %%
for data in datasets:
    datasets[data].rename(columns={data: 'poi'}, inplace=True)
    datasets[data]['category'] = data
    all_data = pd.concat([all_data, datasets[data]], ignore_index=True)

# %%
all_data.columns
# Out:
# Index(['poi', 'place', 'geometry', 'shape', 'name', 'addr:street', 'centroid',
#        'lat', 'lon', 'category', 'id', 'naptan:AtcoCode', 'naptan:Bearing',
#        'naptan:CommonName', 'naptan:Indicator', 'naptan:verified',
#        'public_transport', 'network', 'wikidata', 'wikipedia', 'operator',
#        'wheelchair'],
#       dtype='object')

# %%
all_data = all_data[['category', 'poi', 'place', 'geometry', 'shape', 'name', 'centroid', 'lat', 'lon', 'id']].drop_duplicates()

# %%
all_data
# Out:
#       category                     poi   place  \
# 0      amenity                  school  London
# 1      amenity                  school  London
# 2      amenity                  school  London
# 3      amenity                  school  London
# 4      amenity                  school  London
# ...        ...                     ...     ...
# 44891  railway                 station  London
# 44892  railway  train_station_entrance  London
# 44893  railway  train_station_entrance  London
# 44894  railway  train_station_entrance  London
# 44895  railway  train_station_entrance  London
#
#                                                 geometry    shape  \
# 0      POLYGON ((-0.56590 51.49836, -0.56473 51.49856...  Polygon
# 1      POLYGON ((-0.51036 51.48113, -0.50933 51.48110...  Polygon
# 2      POLYGON ((-0.52434 51.48335, -0.52450 51.48263...  Polygon
# 3      POLYGON ((-0.55224 51.49684, -0.55066 51.49813...  Polygon
# 4      POLYGON ((-0.60874 51.49046, -0.60880 51.49050...  Polygon
# ...                                                  ...      ...
# 44891                           POINT (0.23420 51.59322)    Point
# 44892                           POINT (0.29965 51.61376)    Point
# 44893                           POINT (0.29938 51.61383)    Point
# 44894                           POINT (0.29942 51.61382)    Point
# 44895                           POINT (0.29945 51.61384)    Point
#
#                                              name                   centroid  \
# 0                                             NaN  POINT (-0.56490 51.49764)
# 1                                  Pippins School  POINT (-0.51001 51.48075)
# 2      Colnbrook Church of England Primary School  POINT (-0.52387 51.48271)
# 3                          Langley Grammar School  POINT (-0.55261 51.49843)
# 4                                    Eton College  POINT (-0.60665 51.49489)
# ...                                           ...                        ...
# 44891                                 Harold Wood   POINT (0.23420 51.59322)
# 44892                                         NaN   POINT (0.29965 51.61376)
# 44893                                         NaN   POINT (0.29938 51.61383)
# 44894                                         NaN   POINT (0.29942 51.61382)
# 44895                                         NaN   POINT (0.29945 51.61384)
#
#              lat       lon  id
# 0      51.497639 -0.564903 NaN
# 1      51.480750 -0.510011 NaN
# 2      51.482713 -0.523871 NaN
# 3      51.498430 -0.552611 NaN
# 4      51.494888 -0.606654 NaN
# ...          ...       ...  ..
# 44891  51.593217  0.234200 NaN
# 44892  51.613763  0.299647 NaN
# 44893  51.613825  0.299385 NaN
# 44894  51.613823  0.299416 NaN
# 44895  51.613842  0.299453 NaN
#
# [44760 rows x 10 columns]

# %% [markdown]
# ### Filter points of interest out of the map region (fetcher may get some near the borders due to grid created by the fetch_poi package)

# %%
data_within_boundaries = gpd.sjoin(all_data, fetch.place_map[['geometry']], how='inner').drop(columns=['index_right'])

# %%
data_within_boundaries
# Out:
#       category      poi   place  \
# 328    amenity   school  London
# 329    amenity   school  London
# 330    amenity   school  London
# 331    amenity   school  London
# 332    amenity   school  London
# ...        ...      ...     ...
# 44886  railway  station  London
# 44887  railway  station  London
# 44889  railway  station  London
# 44890  railway  station  London
# 44891  railway  station  London
#
#                                                 geometry    shape  \
# 328    POLYGON ((-0.40022 51.47024, -0.39988 51.47038...  Polygon
# 329    POLYGON ((-0.40970 51.48567, -0.41017 51.48612...  Polygon
# 330    POLYGON ((-0.42208 51.44957, -0.42413 51.44819...  Polygon
# 331    POLYGON ((-0.40856 51.49096, -0.40864 51.49079...  Polygon
# 332    POLYGON ((-0.40969 51.48305, -0.40979 51.48314...  Polygon
# ...                                                  ...      ...
# 44886                           POINT (0.23477 51.55827)    Point
# 44887                           POINT (0.21811 51.55387)    Point
# 44889                           POINT (0.20573 51.58179)    Point
# 44890                           POINT (0.22024 51.56860)    Point
# 44891                           POINT (0.23420 51.59322)    Point
#
#                                    name                   centroid        lat  \
# 328    Beavers Community Primary School  POINT (-0.40025 51.46926)  51.469264
# 329          Cranford Community College  POINT (-0.40826 51.48754)  51.487541
# 330           Southville Primary School  POINT (-0.42178 51.44886)  51.448857
# 331      The Old Rectory Nursery School  POINT (-0.40844 51.49066)  51.490663
# 332           The Cedars Primary School  POINT (-0.41015 51.48421)  51.484212
# ...                                 ...                        ...        ...
# 44886                  Upminster Bridge   POINT (0.23477 51.55827)  51.558265
# 44887                        Hornchurch   POINT (0.21811 51.55387)  51.553875
# 44889                        Gidea Park   POINT (0.20573 51.58179)  51.581785
# 44890                      Emerson Park   POINT (0.22024 51.56860)  51.568601
# 44891                       Harold Wood   POINT (0.23420 51.59322)  51.593217
#
#             lon  id
# 328   -0.400250 NaN
# 329   -0.408256 NaN
# 330   -0.421782 NaN
# 331   -0.408439 NaN
# 332   -0.410154 NaN
# ...         ...  ..
# 44886  0.234769 NaN
# 44887  0.218109 NaN
# 44889  0.205728 NaN
# 44890  0.220238 NaN
# 44891  0.234200 NaN
#
# [37868 rows x 10 columns]

# %% [markdown]
# ## Ingest with mlrun

# %%
import mlrun
import yaml

# %%
project = mlrun.get_or_create_project("application-runtime", "./", user_project=True, )
# Out:
# > 2024-09-16 14:45:19,744 [info] Created and saved project: {"context":"./","from_template":null,"name":"application-runtime-felipe","overwrite":false,"save":true}
# > 2024-09-16 14:45:19,746 [info] Project created successfully: {"project_name":"application-runtime-felipe","stored_in_db":true}

# %%
project.set_source(source="git://github.com/felipenv/application-runtime-demo.git#main", pull_at_runtime=True)

# %%
config = yaml.safe_load(open("config/config.yaml"))

# %%
function = project.set_function('src/ingest.py',
                                  name='ingest-geo', 
                                  kind='job',
                                  image='mlrun/mlrun', 
                                  requirements=['geojson', 'geopandas', 'h3pandas','osmnx','overpy', 'pandas', 'h3', 'tobler'], 
                                  with_repo=True,
                                  handler='fetch')

# %%
#function.deploy()

# %%
function.to_dict()
# Out:
# {'spec': {'image': '',
#   'description': '',
#   'state_thresholds': {'pending_scheduled': '1h',
#    'pending_not_scheduled': '-1',
#    'image_pull_backoff': '1h',
#    'executing': '24h'},
#   'command': 'src/ingest.py',
#   'build': {'source': './',
#    'base_image': 'mlrun/mlrun',
#    'requirements': ['geojson',
#     'geopandas',
#     'h3pandas',
#     'osmnx',
#     'overpy',
#     'pandas',
#     'h3',
#     'tobler']},
#   'priority_class_name': 'igz-workload-medium',
#   'disable_auto_mount': False,
#   'default_handler': 'fetch',
#   'preemption_mode': 'prevent',
#   'resources': {'requests': {'memory': '1Mi', 'cpu': '25m'},
#    'limits': {'memory': '20Gi', 'cpu': '2'}},
#   'tolerations': None,
#   'affinity': {'nodeAffinity': {'requiredDuringSchedulingIgnoredDuringExecution': {'nodeSelectorTerms': [{'matchExpressions': [{'key': 'spot',
#          'operator': 'NotIn',
#          'values': ['true']}]}]}}},
#   'node_selector': {}},
#  'kind': 'job',
#  'metadata': {'project': 'application-runtime-felipe',
#   'name': 'ingest-geo',
#   'tag': 'latest'},
#  'verbose': False}

# %%
get_data_run = project.run_function("ingest-geo", params={"config":config}, auto_build=True, local=False, returns=['pois', 'hexes'])
# Out:
# > 2024-09-16 14:45:59,596 [error] error getting build status: details: MLRunNotFoundError('Function tag not found application-runtime-felipe/ingest-geo:latest'), caused by: 404 Client Error: Not Found for url: http://mlrun-api:8080/api/v1/build/status?name=ingest-geo&project=application-runtime-felipe&tag=latest&logs=no&offset=0&last_log_timestamp=0.0&verbose=no
# > 2024-09-16 14:45:59,596 [info] Function is not deployed and auto_build flag is set, starting deploy...
# > 2024-09-16 14:45:59,928 [info] Started building image: .mlrun/func-application-runtime-felipe-ingest-geo:latest
# > 2024-09-16 14:47:38,678 [info] Storing function: {"db":"http://mlrun-api:8080","name":"ingest-geo-fetch","uid":"9b779647a1b047f6b0ba59089e7c12ae"}
# > 2024-09-16 14:47:38,943 [info] Job is running in the background, pod: ingest-geo-fetch-dz5ml
# > 2024-09-16 14:47:45,085 [info] extracting source from git://github.com/felipenv/application-runtime-demo.git#main to /mlrun/code
# The `utils.config` function is deprecated and will be removed in the v2.0.0 release. Instead, use the `settings` module directly to configure a global setting's value. For example, `ox.settings.log_console=True`. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
# The `utils.config` function is deprecated and will be removed in the v2.0.0 release. Instead, use the `settings` module directly to configure a global setting's value. For example, `ox.settings.log_console=True`. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
# The `utils.config` function is deprecated and will be removed in the v2.0.0 release. Instead, use the `settings` module directly to configure a global setting's value. For example, `ox.settings.log_console=True`. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
# 2024-09-16 14:47:46 Pausing 1 second(s) before making HTTP GET request to 'nominatim.openstreetmap.org'
# 2024-09-16 14:47:47 Get https://nominatim.openstreetmap.org/search?format=json&polygon_geojson=1&dedupe=0&limit=50&q=London with timeout=180
# 2024-09-16 14:47:48 Downloaded 637.6kB from 'nominatim.openstreetmap.org' with status 200
# 2024-09-16 14:47:48 Saved response to cache file 'cache/3f70f87e6c521082caf46af7cc355385bfaff00d.json'
# 2024-09-16 14:47:48 Created GeoDataFrame with 1 rows from 1 queries
# fetching amenity
# 2024-09-16 14:47:49 Retrieved response from cache file 'cache/3f70f87e6c521082caf46af7cc355385bfaff00d.json'
# 2024-09-16 14:47:49 Created GeoDataFrame with 1 rows from 1 queries
# 100%|██████████| 9/9 [00:00<00:00, 891.73it/s]
# INFO:root:getting data per grid for London....
#
# 100%|██████████| 33/33 [01:24<00:00,  2.57s/it]
# INFO:root:Computing geometry from lat, lon
# INFO:root:Computing circles of interest based on parameters k and d.
#                       current values: k = 100, d = 500
# Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
# INFO:root:getting hexagons influenced by POI according to distances k and d...
# CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:3035
# Right CRS: None
#
# INFO:root:filtering POIs matching hexes...
# CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:3035
#
# INFO:root:computing scores for data...
# INFO:root:getting distances between poi and hexagon centroids...
# fetching shop
# 100%|██████████| 9/9 [00:00<00:00, 960.31it/s]
# INFO:root:getting data per grid for London....
#
# 100%|██████████| 33/33 [00:54<00:00,  1.66s/it]
# INFO:root:Computing geometry from lat, lon
# INFO:root:Computing circles of interest based on parameters k and d.
#                       current values: k = 100, d = 500
# Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
# INFO:root:getting hexagons influenced by POI according to distances k and d...
# CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:3035
# Right CRS: None
#
# INFO:root:filtering POIs matching hexes...
# CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:3035
#
# INFO:root:computing scores for data...
# INFO:root:getting distances between poi and hexagon centroids...
# fetching leisure
# 100%|██████████| 9/9 [00:00<00:00, 975.39it/s]
# INFO:root:getting data per grid for London....
#
# 100%|██████████| 33/33 [00:49<00:00,  1.52s/it]
# INFO:root:Computing geometry from lat, lon
# INFO:root:Computing circles of interest based on parameters k and d.
#                       current values: k = 100, d = 500
# Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
# INFO:root:getting hexagons influenced by POI according to distances k and d...
# CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:3035
# Right CRS: None
#
# INFO:root:filtering POIs matching hexes...
# CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:3035
#
# INFO:root:computing scores for data...
# INFO:root:getting distances between poi and hexagon centroids...
# fetching highway
# 100%|██████████| 9/9 [00:00<00:00, 939.96it/s]
# INFO:root:getting data per grid for London....
#
# 100%|██████████| 33/33 [00:56<00:00,  1.70s/it]
# INFO:root:Computing geometry from lat, lon
# INFO:root:Computing circles of interest based on parameters k and d.
#                       current values: k = 100, d = 500
# Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
# INFO:root:getting hexagons influenced by POI according to distances k and d...
# CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:3035
# Right CRS: None
#
# INFO:root:filtering POIs matching hexes...
# CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:3035
#
# INFO:root:computing scores for data...
# INFO:root:getting distances between poi and hexagon centroids...
# fetching railway
# 100%|██████████| 9/9 [00:00<00:00, 930.44it/s]
# INFO:root:getting data per grid for London....
#
# 100%|██████████| 33/33 [00:36<00:00,  1.12s/it]
# INFO:root:Computing geometry from lat, lon
# INFO:root:Computing circles of interest based on parameters k and d.
#                       current values: k = 100, d = 500
# Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
# INFO:root:getting hexagons influenced by POI according to distances k and d...
# CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:3035
# Right CRS: None
#
# INFO:root:filtering POIs matching hexes...
# CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:3035
#
# INFO:root:computing scores for data...
# INFO:root:getting distances between poi and hexagon centroids...
# > 2024-09-16 14:53:09,225 [info] Using the default packager to pack the object 'pois'
# > 2024-09-16 14:53:09,318 [info] Using the default packager to pack the object 'hexes'
# > 2024-09-16 14:53:09,568 [info] To track results use the CLI: {"info_cmd":"mlrun get run 9b779647a1b047f6b0ba59089e7c12ae -p application-runtime-felipe","logs_cmd":"mlrun logs 9b779647a1b047f6b0ba59089e7c12ae -p application-runtime-felipe"}
# > 2024-09-16 14:53:09,568 [info] Or click for UI: {"ui_url":"https://dashboard.default-tenant.app.cust-cs-il-355.iguazio-cd1.com/mlprojects/application-runtime-felipe/jobs/monitor/9b779647a1b047f6b0ba59089e7c12ae/overview"}
# > 2024-09-16 14:53:09,568 [info] Run execution finished: {"name":"ingest-geo-fetch","status":"completed"}
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #4EC64B;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#
#   // Get the base URL of the current notebook
#   var baseUrl = window.location.origin;
#
#   // Construct the full URL
#   var fullUrl = new URL(el.title, baseUrl).href;
#
#   document.querySelector(panelName + "-title").innerHTML = fullUrl
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (fullUrl.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", fullUrl);
#   oReq.send();
#
#
#   //iframe.src = fullUrl;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>project</th>
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>kind</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>application-runtime-felipe</td>
#       <td><div title="9b779647a1b047f6b0ba59089e7c12ae"><a href="https://dashboard.default-tenant.app.cust-cs-il-355.iguazio-cd1.com/mlprojects/application-runtime-felipe/jobs/monitor/9b779647a1b047f6b0ba59089e7c12ae/overview" target="_blank" >...9e7c12ae</a></div></td>
#       <td>0</td>
#       <td>Sep 16 14:47:45</td>
#       <td>completed</td>
#       <td>run</td>
#       <td>ingest-geo-fetch</td>
#       <td><div class="dictlist">v3io_user=felipe</div><div class="dictlist">kind=job</div><div class="dictlist">owner=felipe</div><div class="dictlist">mlrun/client_version=1.7.0-rc43</div><div class="dictlist">mlrun/client_python_version=3.9.18</div><div class="dictlist">host=ingest-geo-fetch-dz5ml</div></td>
#       <td></td>
#       <td><div class="dictlist">config={'location': 'London', 'h3_resolution': 8, 'overpass_endpoint': 'https://overpass-api.de/api/interpreter', 'datasets': {'amenity': {'tag': 'amenity', 'values': ['school', 'hospital', 'pub', 'restaurant'], 'weight': 0.2}, 'shop': {'tag': 'shop', 'values': ['supermarket'], 'weight': 0.2}, 'leisure': {'tag': 'leisure', 'values': ['fitness_centre', 'swimming_pool'], 'weight': 0.2}, 'highway': {'tag': 'highway', 'values': ['bus_stop'], 'weight': 0.2}, 'railway': {'tag': 'railway', 'values': ['station', 'tram_stop'], 'weight': 0.2}}, 'plots': {'mapbox_token': 'pk.eyJ1IjoibWFja2xhcnMiLCJhIjoiY2w2dXo2OGRvMWh0MzNmcGJ3eDQyNDBrOCJ9.uyOgYliAIB1EZ8xWWyH1BQ', 'zoom': 7, 'center': {'lat': 51.5, 'lon': -0.07}, 'pois': {'hover_info': ['category', 'poi', 'name'], 'colors': {'amenity': 'purple', 'shop': '#EC9706', 'leisure': 'brown', 'highway': '#ED7014', 'railway': '#AAFF00'}}, 'hexes': {'hover_info': ['hex_id', 'score'], 'palette': 'RdYlGn'}}}</div></td>
#       <td></td>
#       <td><div title="v3io:///projects/application-runtime-felipe/artifacts/ingest-geo-fetch/0/pois.pkl">pois</div><div title="v3io:///projects/application-runtime-felipe/artifacts/ingest-geo-fetch/0/hexes.pkl">hexes</div></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="result855644c1-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="result855644c1-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="result855644c1" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="result855644c1-body"></iframe>
#   </div>
# </div>
# <b> > to track results use the .show() or .logs() methods  or <a href="https://dashboard.default-tenant.app.cust-cs-il-355.iguazio-cd1.com/mlprojects/application-runtime-felipe/jobs/monitor/9b779647a1b047f6b0ba59089e7c12ae/overview" target="_blank">click here</a> to open in UI</b>
# > 2024-09-16 14:53:15,083 [info] Run execution finished: {"name":"ingest-geo-fetch","status":"completed"}

# %% [markdown]
# ## Verify if data is present in artifacts

# %%
pois = get_data_run.artifact('pois')
hexes = get_data_run.artifact('hexes')

# %% [markdown]
# #### Unpack artifacts of geodataframe type. Must tell the Package Manager what's the data type

# %%
from geopandas import GeoDataFrame
packager = mlrun.package.packagers_manager.PackagersManager()
pois = packager.unpack(pois, type_hint=GeoDataFrame)
hexes = packager.unpack(hexes, type_hint=GeoDataFrame)
# Out:
# > 2024-09-16 14:57:51,677 [info] downloading v3io:///projects/application-runtime-felipe/artifacts/ingest-geo-fetch/0/pois.pkl to local temp file
# > 2024-09-16 14:57:51,723 [warning] MLRun is trying to load an object that was pickled on python version '3.9.19' but the current python version is '3.9.18'. When using pickle, it is recommended to save and load an object on the same python version to reduce unexpected errors.
# > 2024-09-16 14:57:51,973 [info] downloading v3io:///projects/application-runtime-felipe/artifacts/ingest-geo-fetch/0/hexes.pkl to local temp file
# > 2024-09-16 14:57:51,981 [warning] MLRun is trying to load an object that was pickled on python version '3.9.19' but the current python version is '3.9.18'. When using pickle, it is recommended to save and load an object on the same python version to reduce unexpected errors.

# %%
type(pois)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
pois
# Out:
#       category      poi   place  \
# 344    amenity   school  London
# 345    amenity   school  London
# 346    amenity   school  London
# 347    amenity   school  London
# 348    amenity   school  London
# ...        ...      ...     ...
# 44914  railway  station  London
# 44915  railway  station  London
# 44917  railway  station  London
# 44918  railway  station  London
# 44919  railway  station  London
#
#                                                 geometry    shape  \
# 344    POLYGON ((-0.40022 51.47024, -0.39988 51.47038...  Polygon
# 345    POLYGON ((-0.40970 51.48567, -0.41017 51.48612...  Polygon
# 346    POLYGON ((-0.42208 51.44957, -0.42413 51.44819...  Polygon
# 347    POLYGON ((-0.40856 51.49096, -0.40864 51.49079...  Polygon
# 348    POLYGON ((-0.40969 51.48305, -0.40979 51.48314...  Polygon
# ...                                                  ...      ...
# 44914                           POINT (0.23477 51.55827)    Point
# 44915                           POINT (0.21811 51.55387)    Point
# 44917                           POINT (0.20573 51.58179)    Point
# 44918                           POINT (0.22024 51.56860)    Point
# 44919                           POINT (0.23420 51.59322)    Point
#
#                                    name                   centroid        lat  \
# 344    Beavers Community Primary School  POINT (-0.40025 51.46926)  51.469264
# 345          Cranford Community College  POINT (-0.40826 51.48754)  51.487541
# 346           Southville Primary School  POINT (-0.42178 51.44886)  51.448857
# 347      The Old Rectory Nursery School  POINT (-0.40844 51.49066)  51.490663
# 348           The Cedars Primary School  POINT (-0.41015 51.48421)  51.484212
# ...                                 ...                        ...        ...
# 44914                  Upminster Bridge   POINT (0.23477 51.55827)  51.558265
# 44915                        Hornchurch   POINT (0.21811 51.55387)  51.553875
# 44917                        Gidea Park   POINT (0.20573 51.58179)  51.581785
# 44918                      Emerson Park   POINT (0.22024 51.56860)  51.568601
# 44919                       Harold Wood   POINT (0.23420 51.59322)  51.593217
#
#             lon  id
# 344   -0.400250 NaN
# 345   -0.408256 NaN
# 346   -0.421782 NaN
# 347   -0.408439 NaN
# 348   -0.410154 NaN
# ...         ...  ..
# 44914  0.234769 NaN
# 44915  0.218109 NaN
# 44917  0.205728 NaN
# 44918  0.220238 NaN
# 44919  0.234200 NaN
#
# [37879 rows x 10 columns]

# %%
hexes
# Out:
#                hex_id                                           geometry  \
# 0     88194ac319fffff  POLYGON ((-0.12924 51.37152, -0.13593 51.37032...
# 1     88195da411fffff  POLYGON ((-0.17117 51.56846, -0.17789 51.56727...
# 2     88195da755fffff  POLYGON ((-0.20172 51.64388, -0.20845 51.64269...
# 3     88194e680dfffff  POLYGON ((0.03029 51.60408, 0.02358 51.60290, ...
# 4     88194ac151fffff  POLYGON ((-0.18096 51.34518, -0.18765 51.34398...
# ...               ...                                                ...
# 2401  88194ad9ddfffff  POLYGON ((-0.30040 51.42178, -0.30710 51.42057...
# 2402  88195dae97fffff  POLYGON ((-0.32018 51.53760, -0.32690 51.53640...
# 2403  88195db5d1fffff  POLYGON ((-0.13383 51.68140, -0.14055 51.68022...
# 2404  88194aca6bfffff  POLYGON ((-0.30700 51.37366, -0.31370 51.37245...
# 2405  88194e6c65fffff  POLYGON ((0.14608 51.49273, 0.13938 51.49156, ...
#
#       score_amenity  score_shop  score_leisure  score_highway  score_railway
# 0         14.276499    2.528629       0.280687      32.735134       0.852986
# 1         24.566962    0.481855       6.191345      20.363966       0.579007
# 2          3.639815    0.678248      10.200763      16.924445       0.112831
# 3         22.111656    3.413863       2.221552      41.154421       0.784496
# 4          2.146308    0.108535       0.468924      18.182788       0.170729
# ...             ...         ...            ...            ...            ...
# 2401      40.586922    4.242969       4.970946      53.791511       1.590637
# 2402       9.613247    1.648059       0.207915      26.949379       1.381755
# 2403       0.802176    0.000000       1.000000       5.789776       0.000000
# 2404      11.147009    0.626548       1.262218      25.593025       0.611944
# 2405      13.226498    1.255917       0.224239      40.599457       0.553339
#
# [2406 rows x 7 columns]
